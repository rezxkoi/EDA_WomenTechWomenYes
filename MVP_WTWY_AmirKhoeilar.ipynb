# %% [markdown]
# # Minimum Viable Product (MVP) for WTWY

# %% [markdown]
# WomenTechWomenYes!
# empowering women to step into the field of technology
#
# GALA DATE:
# To be held june 2022.
#
# COLLECTED DATA:
# Three months of March, April and May 2021

# %% [markdown]
# As requested by the proposal, the goal is to gather as many signitures ( to send out tickets to emails) possible for the GALA that is going to be held in the June 2022.
#
# It would be simplest to gather these signitures at the HIGH TRAFFIC STATIONS.
#
# High Traffic means the maximum enteries and exits from an station.

# %% [markdown]
# In order to reach the best/simplest conclusion, captured data has been 3 months before the gala month in the year of 2021. It help us undersand:
#
# 1.High Traffic Stations
#
# and eventually with knowing that we can focus on:
#
# 2.HOURS
#
# 3.DAY OF THE WEEK
#
# in order to gather as mmany signitures as possible.

# %% [markdown]
#     RANK	STATION	    TOTAL TRAFFIC
#     1	34 ST-PENN STA	8193865
#     2	34 ST-HERALD SQ   7575251
#     3	86 ST	         6705809
#     4	125 ST	        6393948
#     5	GRD CNTRL-42 ST   5685479
#     6	23 ST	         5485168
#     7	PATH NEW WTC	  5421969
#     8	TIMES SQ-42 ST	5102331
#     9	14 ST-UNION SQ	4823776
#     10   28 ST	         4744201

# %% [markdown]
# In the table:
# The STATIONS with the highest traffic of people have been shown in our focused 3 months. The total traffic of each station in the 3 months have been shown as above.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In the bar plot above:
# The top 10 station have been sorted from left to right in accordance with their total Traffic information. The higher the traffic , the more signitures could be gathered for the WTWY GALA.
